# %%
# !pip install networkx
# Out:
# Requirement already satisfied: networkx in c:\users\srini\anaconda3\lib\site-packages (2.3)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\srini\anaconda3\lib\site-packages (from networkx) (4.4.0)

# %%
import networkx as nx
g_symmetric = nx.Graph() # Initialized an empty network
g_symmetric.add_edge('Amitabh', 'Dev')
g_symmetric.add_edge('Amitabh', 'Aamir')
g_symmetric.add_edge('Amitabh', 'Abhishek')
g_symmetric.add_edge('Amitabh', 'Akshay')
g_symmetric.add_edge('Abhishek', 'Aamir')
g_symmetric.add_edge('Abhishek', 'Dev')
g_symmetric.add_edge('Abhishek', 'Akshay')
g_symmetric.add_edge('Dev', 'Aamir')

# %%
import matplotlib
# %matplotlib inline

# %%
nx.draw_networkx(g_symmetric)
print(nx.degree(g_symmetric, "Amitabh"))
nx.average_clustering(g_symmetric)
# Out:
# 4
# 0.8666666666666666

# %%
g_asymmetric = nx.DiGraph() #  empty network
g_asymmetric.add_edge("A","B")
g_asymmetric.add_edge("C","A")
g_asymmetric.add_edge("A","D")
g_asymmetric.add_edge("D","E")
nx.draw_networkx(g_asymmetric)

# %%
# weighted_graph
g_weighted = nx.Graph()
g_weighted.add_edge('Amitabh', 'Dev', weight=4)
g_weighted.add_edge('Amitabh', 'Akshay', weight=8)
g_weighted.add_edge('Amitabh', 'Aamir', weight=12)
g_weighted.add_edge('Amitabh', 'Abhishek', weight=2)
g_weighted.add_edge('Abhishek', 'Aamir', weight=3)
g_weighted.add_edge('Abhishek', 'Dev', weight=1)
g_weighted.add_edge('Abhishek', 'Akshay', weight=9)
g_weighted.add_edge('Dev', 'Aamir', weight=2)
nx.draw_networkx(g_weighted)

# %%
influ = nx.betweenness_centrality(g_symmetric)
influ
sorted(influ.items(), key = lambda x:x[1], reverse = True)
# Out:
# [('Amitabh', 0.16666666666666666),
#  ('Abhishek', 0.16666666666666666),
#  ('Dev', 0.0),
#  ('Aamir', 0.0),
#  ('Akshay', 0.0)]

# %%
fb_graph = nx.read_edgelist("./facebook_combined.txt")

# %%
nx.draw_networkx(fb_graph)

# %%
nx.info(fb_graph)
# Out:
# 'Name: \nType: Graph\nNumber of nodes: 4039\nNumber of edges: 88234\nAverage degree:  43.6910'

# %%
influ = nx.betweenness_centrality(fb_graph)

# %%
sorted(influ.items(), key = lambda x:x[1], reverse = True)[:5]
# Out:
# [('107', 0.4805180785560152),
#  ('1684', 0.3377974497301992),
#  ('3437', 0.23611535735892905),
#  ('1912', 0.2292953395868782),
#  ('1085', 0.14901509211665306)]

# %%
budget_2021_graph = nx.read_edgelist("./budget_2021_processed_data.txt")
nx.info(budget_2021_graph)
# Out:
# 'Name: \nType: Graph\nNumber of nodes: 7635\nNumber of edges: 6909\nAverage degree:   1.8098'

# %%
influ = nx.betweenness_centrality(budget_2021_graph)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-b3cdb2ff2efe> in <module>
# ----> 1 influ = nx.betweenness_centrality(budget_2021_graph)
#
# <C:\Users\srini\Anaconda3\lib\site-packages\decorator.py:decorator-gen-230> in betweenness_centrality(G, k, normalized, weight, endpoints, seed)
#
# ~\Anaconda3\lib\site-packages\networkx\utils\decorators.py in _random_state(func, *args, **kwargs)
#     462         new_args = list(args)
#     463         new_args[random_state_index] = random_state
# --> 464         return func(*new_args, **kwargs)
#     465     return _random_state
#
# ~\Anaconda3\lib\site-packages\networkx\algorithms\centrality\betweenness.py in betweenness_centrality(G, k, normalized, weight, endpoints, seed)
#     117         # single source shortest paths
#     118         if weight is None:  # use BFS
# --> 119             S, P, sigma = _single_source_shortest_path_basic(G, s)
#     120         else:  # use Dijkstra's algorithm
#     121             S, P, sigma = _single_source_dijkstra_path_basic(G, s, weight)
#
# ~\Anaconda3\lib\site-packages\networkx\algorithms\centrality\betweenness.py in _single_source_shortest_path_basic(G, s)
#     245         Dv = D[v]
#     246         sigmav = sigma[v]
# --> 247         for w in G[v]:
#     248             if w not in D:
#     249                 Q.append(w)
#
# ~\Anaconda3\lib\site-packages\networkx\classes\coreviews.py in __iter__(self)
#      48         return len(self._atlas)
#      49
# ---> 50     def __iter__(self):
#      51         return iter(self._atlas)
#      52
#
# KeyboardInterrupt:

# %%
sorted(influ.items(), key = lambda x:x[1], reverse = True)[:5]
# Out:
# [('askanshul', 0.0877089310692145),
#  ('bjp4india', 0.01748080333617934),
#  ('nsitharaman', 0.016936300970679136),
#  ('dainikbhaskar', 0.014056805963456482),
#  ('timesnow', 0.013345059341638028)]
